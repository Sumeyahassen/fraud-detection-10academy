# %%
# import library
import importlib

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
importlib.reload(plt)
# Out:
# <module 'matplotlib.pyplot' from '/home/sumeya/Documents/ai project/fraud-detection-10academy/venv/lib/python3.12/site-packages/matplotlib/pyplot.py'>

# %%
fraud=pd.read_csv('../data/raw/Fraud_Data.csv')
ip_country=pd.read_csv('../data/raw/IpAddress_to_Country.csv')
credit=pd.read_csv('../data/raw/creditcard.csv')
print(fraud.shape,ip_country.shape,credit.shape)
# Out:
# (151112, 11) (138846, 3) (284807, 31)

# %%
print(fraud.info())
print(credit.info())
print(ip_country.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 151112 entries, 0 to 151111
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   user_id         151112 non-null  int64
#  1   signup_time     151112 non-null  str
#  2   purchase_time   151112 non-null  str
#  3   purchase_value  151112 non-null  int64
#  4   device_id       151112 non-null  str
#  5   source          151112 non-null  str
#  6   browser         151112 non-null  str
#  7   sex             151112 non-null  str
#  8   age             151112 non-null  int64
#  9   ip_address      151112 non-null  float64
#  10  class           151112 non-null  int64
# dtypes: float64(1), int64(4), str(6)
# memory usage: 12.7 MB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
# ...

# %%
# fraud data clening
print(f'missing value {fraud.isnull().sum()}') # type: ignore
print(f'duplication data {fraud.duplicated().sum()}') # type: ignore
fraud=fraud.drop_duplicates()
# Out:
# missing value user_id           0
# signup_time       0
# purchase_time     0
# purchase_value    0
# device_id         0
# source            0
# browser           0
# sex               0
# age               0
# ip_address        0
# class             0
# dtype: int64
# duplication data 0

# %%
# conver timestamp
fraud['signup_time']=pd.to_datetime(fraud['signup_time'])
fraud['purchase_time']=pd.to_datetime(fraud['purchase_time'])

# %%
# credit card cleaning
print(f'missing credite {credit.isnull().sum()}')
print(f"duplication {credit.duplicated().sum()}")
credit=credit.drop_duplicates()
credit.duplicated().sum()
# Out:
# missing credite Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64
# duplication 1081
# np.int64(0)

# %%
# explatori data analaysis
# fraud
print('fraud data class desterbution')
print(fraud['class'].value_counts(normalize=True))
# credit card
print("cradit card destribution")
print(credit['Class'].value_counts(normalize=True))
# Out:
# fraud data class desterbution
# class
# 0    0.906354
# 1    0.093646
# Name: proportion, dtype: float64
# cradit card destribution
# Class
# 0    0.998333
# 1    0.001667
# Name: proportion, dtype: float64

# %%
# uni and bi variant
# fraud vizualization
sns.countplot(x='class',data=fraud)
plt.title="class destributon in e-commerse"
plt.show()

# %%
# vizualize using histogram
sns.histplot(data=fraud, x='purchase_value' ,hue='class',bins=50)
print("perchase class destribution in class")
plt.show()
# Out:
# perchase class destribution in class

# %%
# data visualise by broser,sex,source 
sns.catplot(data=fraud,x='browser',hue='class')
plt.show
sns.catplot(data=fraud,x='sex',hue='class')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# source visualise
sns.barplot(data=fraud,x='source',hue='class')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.catplot(data=fraud,x='ip_address',hue='class')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(data=fraud,x='age',hue='class')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10,8))
sns.heatmap(credit.corr(),cmap='coolwarm')
plt.title("corelation heatmap-cradit card")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
